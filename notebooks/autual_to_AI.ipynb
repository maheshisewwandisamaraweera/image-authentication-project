# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshisewwandisamaraweera/image-authentication-project/blob/maheshi/notebooks/autual_to_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate safetensors

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install diffusers transformers accelerate safetensors

# %%
import torch
from diffusers import StableDiffusionImg2ImgPipeline
from PIL import Image
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# ...

# %%
pipe = pipe.to("cuda")

# %%
import os

actual_folder = "/content/drive/MyDrive/image-authentication-project/data/actual/actual_images"
ai_folder = "/content/drive/MyDrive/image-authentication-project/data/ai_generated"

os.makedirs(ai_folder, exist_ok=True)

# %%
import shutil

shutil.rmtree('/content/drive', ignore_errors=True)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

actual_folder = "/content/drive/MyDrive/image-authentication-project/data/actual/actual_images"

print("Images:", len(os.listdir(actual_folder)))
print(os.listdir(actual_folder)[:5])
# Out:
# Images: 189
# ['B011-102.png', 'B004-045.png', 'A018-056.png', 'A024-034.png', 'A025-051.png']

# %%
ai_folder = "/content/drive/MyDrive/image-authentication-project/data/ai_generated"
os.makedirs(ai_folder, exist_ok=True)

# %%
import torch
from diffusers import StableDiffusionImg2ImgPipeline
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# ...

# %%
pipe = pipe.to("cuda")

# %%
print("Model loaded successfully:", pipe)
# Out:
# Model loaded successfully: StableDiffusionImg2ImgPipeline {
#   "_class_name": "StableDiffusionImg2ImgPipeline",
#   "_diffusers_version": "0.37.1",
#   "_name_or_path": "runwayml/stable-diffusion-v1-5",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
import os

actual_folder = "/content/drive/MyDrive/image-authentication-project/data/actual/actual_images"
ai_folder = "/content/drive/MyDrive/image-authentication-project/data/ai_generated"

os.makedirs(ai_folder, exist_ok=True)

# %%
from PIL import Image

prompt = "highly realistic AI generated image, detailed textures, synthetic style, enhanced lighting"

for file in os.listdir(actual_folder):

    img_path = os.path.join(actual_folder, file)

    try:
        init_image = Image.open(img_path).convert("RGB").resize((512, 512))
    except:
        continue

    # AI generation
    result = pipe(
        prompt=prompt,
        image=init_image,
        strength=0.75,
        guidance_scale=7.5
    ).images[0]

    save_path = os.path.join(ai_folder, file)
    result.save(save_path)

    print("Saved:", save_path)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]
# Saved: /content/drive/MyDrive/image-authentication-project/data/ai_generated/B011-102.png
#   0%|          | 0/37 [00:00<?, ?it/s]
# Saved: /content/drive/MyDrive/image-authentication-project/data/ai_generated/B004-045.png
#   0%|          | 0/37 [00:00<?, ?it/s]
# Saved: /content/drive/MyDrive/image-authentication-project/data/ai_generated/A018-056.png
#   0%|          | 0/37 [00:00<?, ?it/s]
# Saved: /content/drive/MyDrive/image-authentication-project/data/ai_generated/A024-034.png
#   0%|          | 0/37 [00:00<?, ?it/s]
# Saved: /content/drive/MyDrive/image-authentication-project/data/ai_generated/A025-051.png
#   0%|          | 0/37 [00:00<?, ?it/s]
# Saved: /content/drive/MyDrive/image-authentication-project/data/ai_generated/A042-459.png
#   0%|          | 0/37 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# ...

# %%
from PIL import Image
import os

sample = os.listdir(ai_folder)[0]
Image.open(os.path.join(ai_folder, sample))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
